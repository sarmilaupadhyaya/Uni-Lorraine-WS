# %%
import pandas as pd

# %% [markdown]
# # 1 Intro #
#
# In this practical, we will see the basic pipeline to process a formal context with
# FCA, and code in Python two basic FCA algorithm.
# We will be using 2 toy datasets from the theoretical class for this practical:
#
# •a 4 by 4 boolean context: shapes.csv;
# •a 9 by 26 multi-valued context: banking.csv.
#
# As those files are CSV files, it is recommended to use the pandas library to
# load them, using pandas.read csv("shapes.csv", index col=0).

# %%
shapes = pd.read_csv("shapes.csv",index_col=0)
banking = pd.read_csv("banking.csv",index_col=0)

# %%
shapes
# Out:
#                       Has 3 Vertices  Has 4 vertices  Has a direct angle  \
# Shape
# Equilateral triangle            True           False               False
# Rectangle triangle              True           False                True
# Rectangle                      False            True                True
# Square                         False            True                True
#
#                       Equilateral
# Shape
# Equilateral triangle         True
# Rectangle triangle          False
# Rectangle                   False
# Square                       True

# %%
banking
# Out:
#               Country    BankType    Owner      Code  CorpC  FinLib  RegInt  \
# Case
# ABNAmro           NLD   Universal   Public        No   0.74    0.98     144
# Barclays          GBR  Commercial   Public  Explicit   0.14    1.00     277
# BNP Paribas       FRA   Universal   Public  Implicit   0.82    1.00      75
# Carnegie          SWE  Investment   Public        No   0.71    0.95      83
# Citigroup         USA  Commercial   Public  Explicit   0.00    1.00     426
# Coutts \& Co      GBR     Private   Public  Implicit   0.14    1.00     277
# CS                CHE   Universal   Public  Explicit   0.44    0.95      83
# Deutsche Bank     GER   Universal   Public  Explicit   0.95    0.90      45
# Goldman Sachs     USA  Investment   Public  Explicit   0.00    1.00     426
# HSBC              GBR  Commercial   Public  Implicit   0.14    1.00     277
# ING               NLD   Universal   Public  Implicit   0.74    0.98     144
# JPMorgan          USA  Commercial   Public  Explicit   0.00    1.00     426
# Julius Baer       CHE     Private   Public        No   0.44    0.95      83
# LCF               FRA     Private  Private        No   0.82    1.00      75
# LODH              CHE     Private  Private        No   0.44    0.95      83
# MeesPierson       NLD     Private   Public        No   0.74    0.98     144
# Merrill Lynch     USA  Investment   Public  Implicit   0.00    1.00     426
# Morgan S          USA  Investment   Public  Explicit   0.14    1.00     277
# Nordea            SWE   Universal   Public  Implicit   0.71    0.95      83
# Pictet & Cie      CHE     Private  Private        No   0.44    0.95      83
# RBC               CAN   Universal   Public  Explicit   0.23    1.00     149
# Rothschild        GBR  Investment  Private        No   0.14    1.00     277
# Santander         ESP   Universal   Public  Explicit   0.77    1.00      53
# SG                FRA   Universal   Public  Explicit   0.82    1.00      75
# UBP               CHE     Private  Private        No   0.44    0.95      83
# UBS               CHE   Universal   Public  Explicit   0.44    0.95      83
#
#               BList Wolfs
# Case
# ABNAmro         Yes    No
# Barclays        Yes   Yes
# BNP Paribas      No    No
# Carnegie         No    No
# Citigroup       Yes   Yes
# Coutts \& Co    Yes    No
# CS              Yes   Yes
# Deutsche Bank    No   Yes
# Goldman Sachs   Yes   Yes
# HSBC            Yes   Yes
# ING             Yes    No
# JPMorgan        Yes   Yes
# Julius Baer     Yes    No
# LCF              No    No
# LODH            Yes    No
# MeesPierson     Yes    No
# Merrill Lynch   Yes    No
# Morgan S        Yes    No
# Nordea           No    No
# Pictet & Cie    Yes    No
# RBC              No    No
# Rothschild      Yes    No
# Santander        No   Yes
# SG               No   Yes
# UBP             Yes    No
# UBS             Yes   Yes

# %% [markdown]
# # 2 Nominal, Ordinal, and Interordinal Scaling #
#
#
# The first thing to do to apply the basic FCA algorithms on data is to transform
# the multi-valued data into a boolean context. While shapes.csv is already a
# Boolean context, banking.csv is not.
# We will see 3 scaling methods in this practical, for some attribute g:
#
#
# •nominal scaling K = (N, N, =):
#
#
# 1. create a Boolean attribute gi for each value i of the attribute g;
#
# 2. for each object, set the value of the attribute gi to T rue if g = i;
#
#
# •ordinal scaling K = (N, N, ≤):
#
#
# 1. create a Boolean attribute g≤i for each value i of the attribute g;
#
# 2. for each object, set the value of the attribute g≤i to T rue if g ≤i;
#
#
# •interordinal scaling K = (N, N, ≤∪≥):
#
#
# 1. create 2 Boolean attributes g≤i and g≥i for each value i of the at-
# tribute g;
#
# 2. for each object, set the value of the attribute g≤i to T rue if g ≤ i
# and similarly for g≥i if g ≥i

# %%
def nominal_operator(attribute, value):
    """
    """
    if attribute == value:
        return True
    else:
        return False

# %%
def ordinal_scaling(attribute_value, value):
    """
    """
    if value <= attribute_value:
        return True
    else:
        return False

# %%
def interordinal_scaling(first_att, second_att, value):
    
    if (value <= first_att) and (value >= second_att):
        return True
    else:
        return False

# %%
# getting unique values from each column and storing in a dictionary

from collections import defaultdict
columns_attribute = defaultdict()
for column in banking:
    print(column)
    unique = banking[column].unique()
    columns_attribute[column] = unique
    print("Unique value for column:", column, " are:")
    print(unique)
    print("---------------------------------------")
# Out:
# Country
# Unique value for column: Country  are:
# ['NLD' 'GBR' 'FRA' 'SWE' 'USA' 'CHE' 'GER' 'CAN' 'ESP']
# ---------------------------------------
# BankType
# Unique value for column: BankType  are:
# ['Universal' 'Commercial' 'Investment' 'Private']
# ---------------------------------------
# Owner
# Unique value for column: Owner  are:
# ['Public' 'Private']
# ---------------------------------------
# Code
# Unique value for column: Code  are:
# ['No' 'Explicit' 'Implicit']
# ---------------------------------------
# CorpC
# Unique value for column: CorpC  are:
# [0.74 0.14 0.82 0.71 0.   0.44 0.95 0.23 0.77]
# ---------------------------------------
# FinLib
# Unique value for column: FinLib  are:
# [0.98 1.   0.95 0.9 ]
# ---------------------------------------
# RegInt
# Unique value for column: RegInt  are:
# [144 277  75  83 426  45 149  53]
# ---------------------------------------
# BList
# Unique value for column: BList  are:
# ['Yes' 'No']
# ---------------------------------------
# Wolfs
# Unique value for column: Wolfs  are:
# ['No' 'Yes']
# ---------------------------------------

# %%
#scaling the columns
nominal_required_columns = ["Country", "BankType", "Owner", "Code"]
ordinal_required_columns = [ "FinLib","RegInt", "CorpC"]
rows = []
new_df = pd.DataFrame([])

for column, unique in columns_attribute.items():
    
    if column in nominal_required_columns:
        for each in unique:
            key_name = column+ "_" + str(each)
            new_df[key_name] = banking.apply(lambda x: nominal_operator(each, x[column]), axis=1)
            
for column, unique in columns_attribute.items():
    if column in ordinal_required_columns:
        for each in unique:
            key_name = column+ "_<=_" + str(each)
            new_df[key_name] = banking.apply(lambda x: ordinal_scaling(each, x[column]), axis=1)
            
        new_df["BList"] = banking["BList"].apply(lambda x: True if x=="Yes" else "False")
new_df["Wolfs"] = banking["Wolfs"].apply(lambda x: True if x=="Yes" else "False")

# %%
new_df
# Out:
#                Country_NLD  Country_GBR  Country_FRA  Country_SWE  \
# Case
# ABNAmro               True        False        False        False
# Barclays             False         True        False        False
# BNP Paribas          False        False         True        False
# Carnegie             False        False        False         True
# Citigroup            False        False        False        False
# Coutts \& Co         False         True        False        False
# CS                   False        False        False        False
# Deutsche Bank        False        False        False        False
# Goldman Sachs        False        False        False        False
# HSBC                 False         True        False        False
# ING                   True        False        False        False
# JPMorgan             False        False        False        False
# Julius Baer          False        False        False        False
# LCF                  False        False         True        False
# LODH                 False        False        False        False
# MeesPierson           True        False        False        False
# Merrill Lynch        False        False        False        False
# Morgan S             False        False        False        False
# Nordea               False        False        False         True
# Pictet & Cie         False        False        False        False
# RBC                  False        False        False        False
# Rothschild           False         True        False        False
# Santander            False        False        False        False
# SG                   False        False         True        False
# UBP                  False        False        False        False
# UBS                  False        False        False        False
#
#                Country_USA  Country_CHE  Country_GER  Country_CAN  \
# Case
# ABNAmro              False        False        False        False
# Barclays             False        False        False        False
# BNP Paribas          False        False        False        False
# Carnegie             False        False        False        False
# Citigroup             True        False        False        False
# Coutts \& Co         False        False        False        False
# CS                   False         True        False        False
# Deutsche Bank        False        False         True        False
# Goldman Sachs         True        False        False        False
# HSBC                 False        False        False        False
# ING                  False        False        False        False
# JPMorgan              True        False        False        False
# Julius Baer          False         True        False        False
# LCF                  False        False        False        False
# LODH                 False         True        False        False
# MeesPierson          False        False        False        False
# Merrill Lynch         True        False        False        False
# Morgan S              True        False        False        False
# Nordea               False        False        False        False
# Pictet & Cie         False         True        False        False
# RBC                  False        False        False         True
# Rothschild           False        False        False        False
# Santander            False        False        False        False
# SG                   False        False        False        False
# UBP                  False         True        False        False
# UBS                  False         True        False        False
#
#                Country_ESP  BankType_Universal  ...  FinLib_<=_0.9  \
# Case                                            ...
# ABNAmro              False                True  ...          False
# Barclays             False               False  ...          False
# BNP Paribas          False                True  ...          False
# Carnegie             False               False  ...          False
# Citigroup            False               False  ...          False
# Coutts \& Co         False               False  ...          False
# CS                   False                True  ...          False
# Deutsche Bank        False                True  ...           True
# Goldman Sachs        False               False  ...          False
# HSBC                 False               False  ...          False
# ING                  False                True  ...          False
# JPMorgan             False               False  ...          False
# Julius Baer          False               False  ...          False
# LCF                  False               False  ...          False
# LODH                 False               False  ...          False
# MeesPierson          False               False  ...          False
# Merrill Lynch        False               False  ...          False
# Morgan S             False               False  ...          False
# Nordea               False                True  ...          False
# Pictet & Cie         False               False  ...          False
# RBC                  False                True  ...          False
# Rothschild           False               False  ...          False
# Santander             True                True  ...          False
# SG                   False                True  ...          False
# UBP                  False               False  ...          False
# UBS                  False                True  ...          False
#
#                RegInt_<=_144  RegInt_<=_277  RegInt_<=_75  RegInt_<=_83  \
# Case
# ABNAmro                 True           True         False         False
# Barclays               False           True         False         False
# BNP Paribas             True           True          True          True
# Carnegie                True           True         False          True
# Citigroup              False          False         False         False
# Coutts \& Co           False           True         False         False
# CS                      True           True         False          True
# Deutsche Bank           True           True          True          True
# Goldman Sachs          False          False         False         False
# HSBC                   False           True         False         False
# ING                     True           True         False         False
# JPMorgan               False          False         False         False
# Julius Baer             True           True         False          True
# LCF                     True           True          True          True
# LODH                    True           True         False          True
# MeesPierson             True           True         False         False
# Merrill Lynch          False          False         False         False
# Morgan S               False           True         False         False
# Nordea                  True           True         False          True
# Pictet & Cie            True           True         False          True
# RBC                    False           True         False         False
# Rothschild             False           True         False         False
# Santander               True           True          True          True
# SG                      True           True          True          True
# UBP                     True           True         False          True
# UBS                     True           True         False          True
#
#                RegInt_<=_426  RegInt_<=_45  RegInt_<=_149  RegInt_<=_53  Wolfs
# Case
# ABNAmro                 True         False           True         False  False
# Barclays                True         False          False         False   True
# BNP Paribas             True         False           True         False  False
# Carnegie                True         False           True         False  False
# Citigroup               True         False          False         False   True
# Coutts \& Co            True         False          False         False  False
# CS                      True         False           True         False   True
# Deutsche Bank           True          True           True          True   True
# Goldman Sachs           True         False          False         False   True
# HSBC                    True         False          False         False   True
# ING                     True         False           True         False  False
# JPMorgan                True         False          False         False   True
# Julius Baer             True         False           True         False  False
# LCF                     True         False           True         False  False
# LODH                    True         False           True         False  False
# MeesPierson             True         False           True         False  False
# Merrill Lynch           True         False          False         False  False
# Morgan S                True         False          False         False  False
# Nordea                  True         False           True         False  False
# Pictet & Cie            True         False           True         False  False
# RBC                     True         False           True         False  False
# Rothschild              True         False          False         False  False
# Santander               True         False           True          True   True
# SG                      True         False           True         False   True
# UBP                     True         False           True         False  False
# UBS                     True         False           True         False   True
#
# [26 rows x 41 columns]

# %% [markdown]
# # 3 Implement the derivation and the closure operator #
#
# ## 3.1 Derivation operator (optional) ##
#
#
# Implement two functions corresponding to the derivation operator from respec-
# tively the set of objects (up) and the set of attributes (down). The function
# should take a Boolean context and a set of objects as input and output a set
# of attributes, for the first function, and take a Boolean context and a set of
# attributes as input and output a set of objects for the second function.
# Reminder of the derivation operator, with gIm if there is a cross1 in the
# context for attribute g of object m:
#
#
# A′ def
# = {m ∈M |gIm for all g ∈A},
#
# B′ def
# = {g ∈G |gIm for all m ∈B}.

# %%
def derivational_operator(list_obj, data, dtype="Object"):
    
    if dtype != "Object":
        result = []
        for each in list_obj:
            result.append(data.index[data[each] == True].tolist())
            
        #get index
    else:
        result = []
        for each in list_obj:
            row = data.loc[each].to_dict()
            result.append([k for k,v in row.items() if v == True])
    if len(result) == 0:
        return {}
    return set.intersection(*map(set,result))

# %%
derivational_operator(["RBC","Rothschild"], new_df)
# Out:
# {'CorpC_<=_0.23',
#  'CorpC_<=_0.44',
#  'CorpC_<=_0.71',
#  'CorpC_<=_0.74',
#  'CorpC_<=_0.77',
#  'CorpC_<=_0.82',
#  'CorpC_<=_0.95',
#  'FinLib_<=_1.0',
#  'RegInt_<=_277',
#  'RegInt_<=_426'}

# %% [markdown]
# ## 3.2 Closure operator ##
# Implement the closure operator on the attributes of a context, by writing a
# function taking a context and a set of attributes as input and returning a set of
# attributes.
#
# Reminder of the closure operator: A′′ = (A′)′.
#
# Check that your code works correctly by computing (A′′)′′ for some set of
# attribute A, which should be equal to A′′ (and to ((A′′)′′)′′ ...). Do so for
# shapes.csv and banking.csv.

# %%
def closure(attributes, data):
    
    objects = derivational_operator(attributes, data, dtype="Objectf")
    data = data.loc[objects]
    assert len(data) == len(objects)
    attributes = derivational_operator(list(objects), data, dtype="Object")
    return attributes

# %%
closure(['CorpC_<=_0.23','FinLib_<=_1.0'], new_df[['CorpC_<=_0.23','FinLib_<=_1.0']])
# Out:
# {'CorpC_<=_0.23', 'FinLib_<=_1.0'}

# %% [markdown]
# ## 4 Implement AllClosure ##

# %%
attribute_indices = {k:i for i,k in enumerate(new_df.columns)}
indices_attribute = {i:k for i,k in enumerate(new_df.columns)}
def NextIntent(B, data, n):
    for i in range(n-1, 0, -1):
        res = set(range(i)).intersection(B)
        B_n = {indices_attribute[x] for x in res}
        B_n.add(indices_attribute[i])
        Bh = derivational_operator(derivational_operator(list(B_n), data, dtype="attribute"), data, dtype="Object" )
        Bh_n= [ attribute_indices[x] for x in Bh]
        if LexicoLessThan(B, Bh_n, i): return Bh

def LexicoLessThan(B, Bh, i):
    if i not in [e for e in Bh if e not in B]: return False
    h = set(range(i))
    if h.intersection(B) == h.intersection(Bh): return True
    else:
        return False

# %%
attributes = ['CorpC_<=_0.23','FinLib_<=_1.0']
B = [attribute_indices[x] for x in attributes]
NextIntent(B, new_df, len(new_df.columns))
# Out:
# {25, 29}
# {'FinLib_<=_1.0', 'CorpC_<=_0.14', 'Wolfs', 'BList', 'CorpC_<=_0.74', 'RegInt_<=_426', 'CorpC_<=_0.23', 'CorpC_<=_0.44', 'Owner_Public', 'CorpC_<=_0.71', 'CorpC_<=_0.77', 'CorpC_<=_0.82', 'CorpC_<=_0.95'}
# [29, 19, 40, 27, 18, 36, 25, 23, 13, 21, 26, 20, 24]
# {25, 29}
# {}
# []
# {25, 29}
# {'RegInt_<=_277', 'Country_CAN', 'FinLib_<=_1.0', 'CorpC_<=_0.74', 'RegInt_<=_149', 'RegInt_<=_426', 'CorpC_<=_0.23', 'BankType_Universal', 'Code_Explicit', 'CorpC_<=_0.71', 'Owner_Public', 'CorpC_<=_0.44', 'CorpC_<=_0.77', 'CorpC_<=_0.82', 'CorpC_<=_0.95'}
# [33, 7, 29, 18, 38, 36, 25, 9, 16, 21, 13, 23, 26, 20, 24]
# {25, 29}
# {}
# []
# {25, 29}
# {'FinLib_<=_1.0', 'CorpC_<=_0.74', 'RegInt_<=_426', 'CorpC_<=_0.23', 'CorpC_<=_0.44', 'CorpC_<=_0.71', 'CorpC_<=_0.77', 'CorpC_<=_0.82', 'CorpC_<=_0.95'}
# [29, 18, 36, 25, 23, 21, 26, 20, 24]
# {25, 29}
# {}
# []
# {25, 29}
# {}
# []
# {25, 29}
# {'RegInt_<=_277', 'FinLib_<=_1.0', 'CorpC_<=_0.74', 'RegInt_<=_426', 'CorpC_<=_0.23', 'CorpC_<=_0.44', 'CorpC_<=_0.71', 'CorpC_<=_0.77', 'CorpC_<=_0.82', 'CorpC_<=_0.95'}
# [33, 29, 18, 36, 25, 23, 21, 26, 20, 24]
# {25, 29}
# {}
# []
# {25, 29}
# {}
# []
# {25, 29}
# {}
# []
# {25}
# {'FinLib_<=_1.0', 'CorpC_<=_0.74', 'RegInt_<=_426', 'CorpC_<=_0.23', 'CorpC_<=_0.44', 'CorpC_<=_0.71', 'CorpC_<=_0.77', 'CorpC_<=_0.82', 'CorpC_<=_0.95'}
# [29, 18, 36, 25, 23, 21, 26, 20, 24]
# {25}
# {}
# []
# {25}
# {'FinLib_<=_1.0', 'CorpC_<=_0.14', 'BList', 'CorpC_<=_0.74', 'RegInt_<=_426', 'CorpC_<=_0.23', 'CorpC_<=_0.44', 'CorpC_<=_0.71', 'CorpC_<=_0.77', 'CorpC_<=_0.82', 'CorpC_<=_0.95'}
# [29, 19, 27, 18, 36, 25, 23, 21, 26, 20, 24]
# {25}
# {'FinLib_<=_1.0', 'CorpC_<=_0.74', 'RegInt_<=_426', 'CorpC_<=_0.23', 'CorpC_<=_0.44', 'CorpC_<=_0.71', 'CorpC_<=_0.77', 'CorpC_<=_0.82', 'CorpC_<=_0.95'}
# [29, 18, 36, 25, 23, 21, 26, 20, 24]
# set()
# {'FinLib_<=_1.0', 'CorpC_<=_0.74', 'RegInt_<=_426', 'CorpC_<=_0.23', 'CorpC_<=_0.44', 'CorpC_<=_0.71', 'CorpC_<=_0.77', 'CorpC_<=_0.82', 'CorpC_<=_0.95'}
# [29, 18, 36, 25, 23, 21, 26, 20, 24]
# set()
# {'RegInt_<=_426', 'FinLib_<=_1.0', 'CorpC_<=_0.95'}
# [36, 29, 24]
# {'CorpC_<=_0.95', 'FinLib_<=_1.0', 'RegInt_<=_426'}

# %% [markdown]
# ## 4.1 Implement NextClosure operator ##
#
# Implement NextClosure using the algorithm from Figure 1. Note that Up is
# the derivation operator from object to attributes, and Down from attributes to
# objects. This version of the algorithm is computed on the attribute indices in the
# lexical order and not the attribute names, so depending on your implementation,
# take care of the modifications.
#
# ## 4.2 Implement AllClosure using NextClosure operator ##
# Implement AllClosure (see slide 22). It will take as an input a Boolean formal
# context. It should output a list of concepts (extent-intent pairs),
# Hint: you will need to store the concepts in a list instead of outputing them
# each time like in 2.1. of slide 22.
